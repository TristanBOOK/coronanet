# %% [markdown]
# # Streamlit trial

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import pyreadr
from matplotlib import pyplot as plt

# %% [markdown]
# # a

# %%
lma_data=pd.read_csv('https://raw.githubusercontent.com/TristanBOOK/coronanet/master/coronanet/data/LMA_Data_10_semaines_and_Pol_fam.csv')

# %%
countries=list(lma_data.ID.unique())

# %%
dataR= pyreadr.read_r('../coronanet/data/COVID-19.RData')
cases_df = pd.DataFrame(dataR['COVID19'])
case=cases_df[cases_df['Type']=='Deaths']
case=case[case['Source']=='JHU']
case=case.drop(['Cases_New'],axis=1)
case=case.drop(['Age'],axis=1)
case=case.drop(['Sex'],axis=1)
case=case.drop(['Source'],axis=1)
case=case.drop(['Type'],axis=1)
case.to_csv('/Users/paulcharpentier/Desktop/Coronanet_files/cases_data.csv')

# %%
#case.to_csv('/Users/paulcharpentier/Desktop/Coronanet_files/cases_data.csv')

# %%
cases=pd.read_csv('/Users/paulcharpentier/Desktop/Coronanet_files/cases_data.csv')

# %%
cases
# Out:
#          Unnamed: 0  ID        Date  Cases
# 0                 2  AD  2020-01-22    0.0
# 1                 6  AD  2020-01-23    0.0
# 2                10  AD  2020-01-24    0.0
# 3                14  AD  2020-01-25    0.0
# 4                18  AD  2020-01-26    0.0
# 5                22  AD  2020-01-27    0.0
# 6                26  AD  2020-01-28    0.0
# 7                30  AD  2020-01-29    0.0
# 8                34  AD  2020-01-30    0.0
# 9                38  AD  2020-01-31    0.0
# 10               42  AD  2020-02-01    0.0
# 11               46  AD  2020-02-02    0.0
# 12               50  AD  2020-02-03    0.0
# 13               54  AD  2020-02-04    0.0
# 14               58  AD  2020-02-05    0.0
# 15               62  AD  2020-02-06    0.0
# 16               66  AD  2020-02-07    0.0
# 17               70  AD  2020-02-08    0.0
# 18               74  AD  2020-02-09    0.0
# 19               78  AD  2020-02-10    0.0
# 20               82  AD  2020-02-11    0.0
# ...

# %%
option='AD'
case=cases[cases['ID']==option]
dte1=case.Date.iloc[case.shape[0]-1]
dte0=case.Date.iloc[case.shape[0]-15]
death=case.Cases.iloc[case.shape[0]-1]-case.Cases.iloc[case.shape[0]-15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-40264ea16e6b> in <module>
#       2 option='AD'
#       3 case=cases[cases['ID']==option]
# ----> 4 dte1=case.Date.iloc[case.shape[0]-1]
#       5 dte0=case.Date.iloc[case.shape[0]-15]
#       6 death=case.Cases.iloc[case.shape[0]-1]-case.Cases.iloc[case.shape[0]-15]
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# ...

# %%
print(death)
print(dte1)
print(dte0)
# Out:
# 5541
# 2020-12-14
# 2020-11-30

# %%
case.head()
# Out:
#    Unnamed: 0  ID        Date  Cases
# 0     3155081  FR  2020-01-22      0
# 1     3155085  FR  2020-01-23      0
# 2     3155091  FR  2020-01-24      0
# 3     3155101  FR  2020-01-25      0
# 4     3155111  FR  2020-01-26      0

# %%
plt.plot(case.Date.values,case.Cases_New.values)
