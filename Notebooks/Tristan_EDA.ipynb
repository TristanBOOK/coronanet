# %%
import pandas as pd
import seaborn as sns
import numpy as np
from IPython.display import display
pd.options.display.max_columns = None
df=pd.read_csv('coronanet_release_allvars.csv',engine = 'python' )

# %%
df.drop(df.columns[0], axis=1)
df.set_index('record_id')
df.head()
# Out:
#    Unnamed: 0            record_id  policy_id entry_type correct_type  \
# 0           1  R_3nCudDknlhUIjpONA    2975738  new_entry     original
# 1           2  R_3OoySQxTamo89oXNA    7024226  new_entry     original
# 2           3  R_3kLn6IU4rQGHtCbNA     889484  new_entry     original
# 3           4  R_1rAmwrNMSZPgFhrNA     129322  new_entry     original
# 4           5  R_21oIyCpRWpNISIDCu    6721435  new_entry   correction
#
#   update_type update_level                                        description  \
# 0         NaN          NaN  March 6, Afghanistan "Measures have been taken...
# 1         NaN          NaN  March 16, In Afghanistan the Government Media ...
# 2         NaN          NaN  Afghanistan, May 28 "a government livelihood s...
# 3         NaN          NaN  Afghanistan, June 28 "Public awareness campaig...
# 4         NaN          NaN  "All schools in Herat – including temporarily ...
#
#   date_announced  date_start date_end      country ISO_A3 ISO_A2  \
# 0     2020-03-06  2020-03-06      NaN  Afghanistan    AFG     AF
# 1     2020-03-16  2020-03-16      NaN  Afghanistan    AFG     AF
# 2     2020-05-28  2020-05-28      NaN  Afghanistan    AFG     AF
# 3     2020-06-28  2020-06-28      NaN  Afghanistan    AFG     AF
# 4     2020-03-09  2020-03-09      NaN  Afghanistan    AFG     AF
#
#   init_country_level  domestic_policy province city  \
# 0           National                0      NaN  NaN
# 1           National                0      NaN  NaN
# 2           National                1      NaN  NaN
# 3           National                0      NaN  NaN
# 4          Municipal                0    Herat  NaN
#
#                                 type  \
# 0       Anti-Disinformation Measures
# 1       Anti-Disinformation Measures
# 2       Anti-Disinformation Measures
# 3       Anti-Disinformation Measures
# 4  Closure and Regulation of Schools
#
#                                         type_sub_cat type_text  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3                                                NaN       NaN
# 4  Preschool or childcare facilities (generally f...       NaN
#
#   institution_status target_country  \
# 0                NaN    Afghanistan
# 1                NaN    Afghanistan
# 2                NaN    Afghanistan
# 3                NaN    Afghanistan
# 4                NaN    Afghanistan
#
#                                    target_geog_level target_region  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  One or more geographical or administrative uni...           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#                                      target_province target_city  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  Balkh; Kabul; Nangarhar; Kunar; Parwan; Kandah...         NaN
# 3                                                NaN         NaN
# 4                                              Herat         NaN
#
#    target_other                                    target_who_what  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN  All Residents (Citizen Residents + Foreign Res...
# 3           NaN                                                NaN
# 4           NaN  All Residents (Citizen Residents + Foreign Res...
#
#   target_direction travel_mechanism                              compliance  \
# 0              NaN              NaN  Voluntary/Recommended but No Penalties
# 1              NaN              NaN         Mandatory (Unspecified/Implied)
# 2              NaN   Not Applicable  Voluntary/Recommended but No Penalties
# 3              NaN              NaN  Voluntary/Recommended but No Penalties
# 4              NaN              NaN         Mandatory (Unspecified/Implied)
#
#                                             enforcer  index_high_est  \
# 0  Ministry/Department of Health,Other (Please sp...       53.029449
# 1  National Government,New (COVID-19 specific) Ta...       53.864544
# 2  National Government,Other (Please specify in t...             NaN
# 3  National Government,Other (Please specify in t...             NaN
# 4                        Provincial/State Government       53.664982
#
#    index_med_est  index_low_est  index_country_rank  \
# 0      50.604971      48.280188               137.0
# 1      52.364609      50.984429               141.0
# 2            NaN            NaN                 NaN
# 3            NaN            NaN                 NaN
# 4      50.916334      48.832111               137.0
#
#                                                 link date_updated  \
# 0  https://www.etilaatroz.com/94246/fears-rumors-...   2020-08-21
# 1  https://www.gmic.gov.af/dari/press-releases2/4...   2020-09-13
# 2  https://www.worldbank.org/en/news/feature/2020...   2020-09-12
# 3  https://www.worldbank.org/en/news/feature/2020...   2020-09-05
# 4  https://reliefweb.int/sites/reliefweb.int/file...   2020-08-10
#
#          recorded_date  confirmed_cases  deaths  recovered  new_tests  \
# 0  2020-08-21 18:32:29              4.0     0.0        0.0        NaN
# 1  2020-09-13 18:56:27             18.0     0.0        1.0        NaN
# 2  2020-09-12 19:08:11          13039.0   236.0     1209.0        NaN
# 3  2020-09-05 18:55:10          30957.0   728.0    12604.0        NaN
# 4  2020-08-10 07:41:49              7.0     0.0        0.0        NaN
#
#    total_tests  total_tests_per_thousand  tests_units  Rank_FP  Score_FP  \
# 0          NaN                       NaN          NaN    120.0    3946.0
# 1          NaN                       NaN          NaN    120.0    3946.0
# 2          NaN                       NaN          NaN    120.0    3946.0
# 3          NaN                       NaN          NaN    120.0    3946.0
# 4          NaN                       NaN          NaN    120.0    3946.0
#
#    state_IDC  muni_IDC  dispersive_IDC  constraining_IDC  inclusive_IDC  \
# 0        1.0       1.0             NaN          0.273704       -0.20141
# 1        1.0       1.0             NaN          0.273704       -0.20141
# 2        1.0       1.0             NaN          0.273704       -0.20141
# 3        1.0       1.0             NaN          0.273704       -0.20141
# 4        1.0       1.0             NaN          0.273704       -0.20141
#
#    sfi_SFI  ti_cpi_TI  pop_WDI_PW    gdp_WDI_PW  gdppc_WDI_PW  growth_WDI_PW  \
# 0     21.0       15.0  32526562.0  2.015838e+10    619.751311       0.840719
# 1     21.0       15.0  32526562.0  2.015838e+10    619.751311       0.840719
# 2     21.0       15.0  32526562.0  2.015838e+10    619.751311       0.840719
# 3     21.0       15.0  32526562.0  2.015838e+10    619.751311       0.840719
# 4     21.0       15.0  32526562.0  2.015838e+10    619.751311       0.840719
#
#    lnpop_WDI_PW  lngdp_WDI_PW  lngdppc_WDI_PW  disap_FA  polpris_FA  \
# 0     17.297568     23.726886        6.429318       2.0         2.0
# 1     17.297568     23.726886        6.429318       2.0         2.0
# 2     17.297568     23.726886        6.429318       2.0         2.0
# 3     17.297568     23.726886        6.429318       2.0         2.0
# 4     17.297568     23.726886        6.429318       2.0         2.0
#
#    latentmean_FA  transparencyindex_HR  EmigrantStock_EMS  v2x_polyarchy_VDEM
# 0      -1.488216             -1.535422          5108886.0            0.355226
# 1      -1.488216             -1.535422          5108886.0            0.355226
# 2      -1.488216             -1.535422          5108886.0            0.355226
# 3      -1.488216             -1.535422          5108886.0            0.355226
# 4      -1.488216             -1.535422          5108886.0            0.355226

# %%
for col in df.columns: 
    print(col)
# Out:
# Unnamed: 0
# record_id
# policy_id
# entry_type
# correct_type
# update_type
# update_level
# description
# date_announced
# date_start
# date_end
# country
# ISO_A3
# ISO_A2
# init_country_level
# domestic_policy
# province
# city
# type
# type_sub_cat
# type_text
# institution_status
# target_country
# target_geog_level
# target_region
# target_province
# target_city
# target_other
# target_who_what
# target_direction
# travel_mechanism
# compliance
# enforcer
# index_high_est
# index_med_est
# index_low_est
# index_country_rank
# link
# date_updated
# recorded_date
# confirmed_cases
# deaths
# recovered
# new_tests
# total_tests
# total_tests_per_thousand
# tests_units
# Rank_FP
# Score_FP
# state_IDC
# muni_IDC
# dispersive_IDC
# constraining_IDC
# inclusive_IDC
# sfi_SFI
# ti_cpi_TI
# pop_WDI_PW
# gdp_WDI_PW
# gdppc_WDI_PW
# growth_WDI_PW
# lnpop_WDI_PW
# lngdp_WDI_PW
# lngdppc_WDI_PW
# disap_FA
# polpris_FA
# latentmean_FA
# transparencyindex_HR
# EmigrantStock_EMS
# v2x_polyarchy_VDEM

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
df.isnull().sum(axis = 0)
# Out:
# Unnamed: 0                 0
# record_id                  0
# policy_id                  0
# entry_type                 0
# correct_type               0
#                         ...
# polpris_FA               892
# latentmean_FA            853
# transparencyindex_HR    9220
# EmigrantStock_EMS       1249
# v2x_polyarchy_VDEM      3021
# Length: 69, dtype: int64

# %%
df_select = df[['record_id',
'policy_id',
'entry_type',
'description',
'date_announced',
'date_start',
'date_end',
'country',
'ISO_A3',
'type',
'type_sub_cat',
'compliance',
]]

# %%
df_select.head()
# Out:
#              record_id  policy_id entry_type  \
# 0  R_3nCudDknlhUIjpONA    2975738  new_entry
# 1  R_3OoySQxTamo89oXNA    7024226  new_entry
# 2  R_3kLn6IU4rQGHtCbNA     889484  new_entry
# 3  R_1rAmwrNMSZPgFhrNA     129322  new_entry
# 4  R_21oIyCpRWpNISIDCu    6721435  new_entry
#
#                                          description date_announced  \
# 0  March 6, Afghanistan "Measures have been taken...     2020-03-06
# 1  March 16, In Afghanistan the Government Media ...     2020-03-16
# 2  Afghanistan, May 28 "a government livelihood s...     2020-05-28
# 3  Afghanistan, June 28 "Public awareness campaig...     2020-06-28
# 4  "All schools in Herat – including temporarily ...     2020-03-09
#
#    date_start date_end      country ISO_A3                               type  \
# 0  2020-03-06      NaN  Afghanistan    AFG       Anti-Disinformation Measures
# 1  2020-03-16      NaN  Afghanistan    AFG       Anti-Disinformation Measures
# 2  2020-05-28      NaN  Afghanistan    AFG       Anti-Disinformation Measures
# 3  2020-06-28      NaN  Afghanistan    AFG       Anti-Disinformation Measures
# 4  2020-03-09      NaN  Afghanistan    AFG  Closure and Regulation of Schools
#
#                                         type_sub_cat  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Preschool or childcare facilities (generally f...
#
#                                compliance
# 0  Voluntary/Recommended but No Penalties
# 1         Mandatory (Unspecified/Implied)
# 2  Voluntary/Recommended but No Penalties
# 3  Voluntary/Recommended but No Penalties
# 4         Mandatory (Unspecified/Implied)

# %%
df_select.isnull().sum(axis = 0)
# Out:
# record_id             0
# policy_id             0
# entry_type            0
# description           0
# date_announced       14
# date_start            0
# date_end          23998
# country               0
# ISO_A3              243
# type                  0
# type_sub_cat      13819
# compliance          244
# dtype: int64

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
df_select.dtypes
# Out:
# record_id         object
# policy_id          int64
# entry_type        object
# description       object
# date_announced    object
# date_start        object
# date_end          object
# country           object
# ISO_A3            object
# type              object
# type_sub_cat      object
# compliance        object
# dtype: object

# %%
df_select['record_id'] =df_select['record_id'].astype('str')
# Out:
# c:\users\user\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_select['entry_type'] =df_select['entry_type'].astype(str)
# Out:
# c:\users\user\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_select.dtypes
# Out:
# record_id         object
# policy_id          int64
# entry_type        object
# description       object
# date_announced    object
# date_start        object
# date_end          object
# country           object
# ISO_A3            object
# type              object
# type_sub_cat      object
# compliance        object
# dtype: object

# %%
df_select[['entry_type','date_announced',
'date_start']]
# Out:
#       entry_type date_announced  date_start
# 0      new_entry     2020-03-06  2020-03-06
# 1      new_entry     2020-03-16  2020-03-16
# 2      new_entry     2020-05-28  2020-05-28
# 3      new_entry     2020-06-28  2020-06-28
# 4      new_entry     2020-03-09  2020-03-09
# ...          ...            ...         ...
# 45635     update     2020-09-17  2020-09-17
# 45636     update     2020-09-17  2020-09-17
# 45637     update     2020-09-17  2020-09-17
# 45638     update     2020-09-17  2020-09-17
# 45639  new_entry     2020-09-22  2020-09-22
#
# [45640 rows x 3 columns]

# %%
df_select['date_announced'] = pd.to_datetime(df_select['date_announced'])
df_select['date_start'] = pd.to_datetime(df_select['date_start'])
df_select['date_end'] = pd.to_datetime(df_select['date_end'])
# Out:
# c:\users\user\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\user\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\user\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_select.dtypes
# Out:
# record_id                 object
# policy_id                  int64
# entry_type                object
# description               object
# date_announced    datetime64[ns]
# date_start        datetime64[ns]
# date_end          datetime64[ns]
# country                   object
# ISO_A3                    object
# type                      object
# type_sub_cat              object
# compliance                object
# dtype: object

# %% [markdown]
# # Remplacer les date_start inferieur au date_anounced par date_announced (question de logique)

# %%
df_select['date_start'] = df_select['date_start'].clip(lower=df_select['date_announced'])
# Out:
# c:\users\user\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_select.loc[df_select['date_announced']> df_select['date_start']]
# Out:
# Empty DataFrame
# Columns: [record_id, policy_id, entry_type, description, date_announced, date_start, date_end, country, ISO_A3, type, type_sub_cat, compliance]
# Index: []

# %% [markdown]
# # Supprimer les updates et corrections en duplicates

# %%
duplicateRowsDF = df_select[df_select['policy_id'].duplicated()]

# %%
duplicateRowsDF
# Out:
#                  record_id  policy_id entry_type  \
# 5      R_21oIyCpRWpNISIDCw    6721435  new_entry
# 6      R_21oIyCpRWpNISIDDr    6721435  new_entry
# 8      R_vCayDsDGFAA6EBbDr    6018486  new_entry
# 9      R_vCayDsDGFAA6EBbBh    6018486  new_entry
# 11     R_2B4LxySA0eoHKmKCw    3558044  new_entry
# ...                    ...        ...        ...
# 45634  R_2dMdrBpRnDMKwS1Af    1599366     update
# 45635  R_2dMdrBpRnDMKwS1Ct    1599366     update
# 45636  R_2dMdrBpRnDMKwS1Am    1599366     update
# 45637  R_2dMdrBpRnDMKwS1Cs    1599366     update
# 45638  R_2dMdrBpRnDMKwS1Ck    1599366     update
#
#                                              description date_announced  \
# 5      "All schools in Herat – including temporarily ...     2020-03-09
# 6      "All schools in Herat – including temporarily ...     2020-03-09
# 8      In parts of northern Samangan province, school...     2020-03-11
# 9      In parts of northern Samangan province, school...     2020-03-11
# 11     "On 14 March, the Government of Afghanistan an...     2020-03-14
# ...                                                  ...            ...
# 45634  In Zimbabwe, restriction of non-essential busi...     2020-09-17
# 45635  In Zimbabwe, restriction of non-essential busi...     2020-09-17
# 45636  In Zimbabwe, restriction of non-essential busi...     2020-09-17
# 45637  In Zimbabwe, restriction of non-essential busi...     2020-09-17
# 45638  In Zimbabwe, restriction of non-essential busi...     2020-09-17
#
#       date_start   date_end      country ISO_A3  \
# 5     2020-03-09        NaT  Afghanistan    AFG
# 6     2020-03-09        NaT  Afghanistan    AFG
# 8     2020-03-11        NaT  Afghanistan    AFG
# 9     2020-03-11        NaT  Afghanistan    AFG
# 11    2020-03-14 2020-04-21  Afghanistan    AFG
# ...          ...        ...          ...    ...
# 45634 2020-09-17 2020-05-17     Zimbabwe    ZWE
# 45635 2020-09-17 2020-05-17     Zimbabwe    ZWE
# 45636 2020-09-17 2020-05-17     Zimbabwe    ZWE
# 45637 2020-09-17 2020-05-17     Zimbabwe    ZWE
# 45638 2020-09-17 2020-05-17     Zimbabwe    ZWE
#
#                                     type  \
# 5      Closure and Regulation of Schools
# 6      Closure and Regulation of Schools
# 8      Closure and Regulation of Schools
# 9      Closure and Regulation of Schools
# 11     Closure and Regulation of Schools
# ...                                  ...
# 45634    Restrictions of Mass Gatherings
# 45635    Restrictions of Mass Gatherings
# 45636    Restrictions of Mass Gatherings
# 45637    Restrictions of Mass Gatherings
# 45638    Restrictions of Mass Gatherings
#
#                                             type_sub_cat  \
# 5      Primary Schools (generally for children ages 1...
# 6      Secondary Schools (generally for children ages...
# 8      Secondary Schools (generally for children ages...
# 9      Higher education institutions (i.e. degree gra...
# 11     Primary Schools (generally for children ages 1...
# ...                                                  ...
# 45634  Annually recurring event allowed to occur with...
# 45635        Postponement of an annually recurring event
# 45636  Cancellation of a recreational or commercial e...
# 45637  Postponement of a recreational or commercial e...
# 45638  Other mass gatherings not specified above rest...
#
#                             compliance
# 5      Mandatory (Unspecified/Implied)
# 6      Mandatory (Unspecified/Implied)
# 8      Mandatory (Unspecified/Implied)
# 9      Mandatory (Unspecified/Implied)
# 11     Mandatory (Unspecified/Implied)
# ...                                ...
# 45634  Mandatory (Unspecified/Implied)
# 45635  Mandatory (Unspecified/Implied)
# 45636  Mandatory (Unspecified/Implied)
# 45637  Mandatory (Unspecified/Implied)
# 45638  Mandatory (Unspecified/Implied)
#
# [20687 rows x 12 columns]

# %% [markdown]
# DROP THE SUBTYPES
